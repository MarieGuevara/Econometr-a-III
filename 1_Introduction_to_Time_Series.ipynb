# %% [markdown]
# <a href="https://colab.research.google.com/github/MarieGuevara/Econometr-a-III/blob/main/1_Introduction_to_Time_Series.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
#import matplotlib.pyplot as plt
#import seaborn as sns
#sns.set()

# %%
url = '/content/drive/MyDrive/Colab Notebooks/TAREA_2_ECONOMETRIA_III/Index_united.csv'
df_comp = pd.read_csv(url)

# %%
df_comp.head()
# Out:
#    Unnamed: 0         spx          dax         ftse        nikkei
# 0         NaN         NaN          NaN          NaN           NaN
# 1        Date         NaN          NaN          NaN           NaN
# 2  1994-01-10  475.269989  2225.000000  3440.600098  18443.439453
# 3  1994-01-11  474.130005  2228.100098  3413.800049  18485.250000
# 4  1994-01-12  474.170013  2182.060059  3372.000000  18793.880859
